# %%
## Data analysis for other datasets

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
columns = ['age', 'sex', 'cp', 'trestbps', 'chol','fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num']

# %%
pwd = Path.resolve(Path("./data/processed.hungarian.data"))
#print(type(pwd))
p_hungarian_df = pd.read_csv(pwd, header=None, names= columns )
p_hungarian_df
# Out:
#      age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0     28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1     29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2     29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3     30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4     31    0   2      100  219   0       1     150     0      0.0     ?  ?
# ..   ...  ...  ..      ...  ...  ..     ...     ...   ...      ...   ... ..
# 289   52    1   4      160  331   0       0      94     1      2.5     ?  ?
# 290   54    0   3      130  294   0       1     100     1      0.0     2  ?
# 291   56    1   4      155  342   1       0     150     1      3.0     2  ?
# 292   58    0   2      180  393   0       0     110     1      1.0     2  ?
# 293   65    1   4      130  275   0       1     115     1      1.0     2  ?
#
#     thal  num
# 0      ?    0
# 1      ?    0
# ...

# %%
pwd = Path.resolve(Path("./data/processed.va.data"))
#print(type(pwd))
p_va_df = pd.read_csv(pwd, header=None, names= columns )
p_va_df
# Out:
#      age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 0     63    1   4      140  260   0        1     112     1       3     2  ?
# 1     44    1   4      130  209   0        1     127     0       0     ?  ?
# 2     60    1   4      132  218   0        1     140     1     1.5     3  ?
# 3     55    1   4      142  228   0        1     149     1     2.5     1  ?
# 4     66    1   3      110  213   1        2      99     1     1.3     2  ?
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...     ...   ... ..
# 195   54    0   4      127  333   1        1     154     0       0     ?  ?
# 196   62    1   1        ?  139   0        1       ?     ?       ?     ?  ?
# 197   55    1   4      122  223   1        1     100     0       0     ?  ?
# 198   58    1   4        ?  385   1        2       ?     ?       ?     ?  ?
# 199   62    1   2      120  254   0        2      93     1       0     ?  ?
#
#     thal  num
# 0      ?    2
# 1      ?    0
# ...

# %%
pwd = Path.resolve(Path("./data/processed.switzerland.data"))
#print(type(pwd))
p_switzerland_df = pd.read_csv(pwd, header=None, names= columns )
p_switzerland_df
# Out:
#      age  sex  cp trestbps  chol fbs restecg thalach exang oldpeak slope ca  \
# 0     32    1   1       95     0   ?       0     127     0      .7     1  ?
# 1     34    1   4      115     0   ?       ?     154     0      .2     1  ?
# 2     35    1   4        ?     0   ?       0     130     1       ?     ?  ?
# 3     36    1   4      110     0   ?       0     125     1       1     2  ?
# 4     38    0   4      105     0   ?       0     166     0     2.8     1  ?
# ..   ...  ...  ..      ...   ...  ..     ...     ...   ...     ...   ... ..
# 118   70    1   4      115     0   0       1      92     1       0     2  ?
# 119   70    1   4      140     0   1       0     157     1       2     2  ?
# 120   72    1   3      160     0   ?       2     114     0     1.6     2  2
# 121   73    0   3      160     0   0       1     121     0       0     1  ?
# 122   74    1   2      145     0   ?       1     123     0     1.3     1  ?
#
#     thal  num
# 0      ?    1
# 1      ?    1
# ...
